# %% [markdown]
# # Task - 2: Restaurant Recommendation System
#
# In this task, we will develop a restaurant recommendation system based on user preferences. The system will allow users to select their desired cuisine and city, and it will recommend the best restaurants based on these choices.
#
# ## Objectives:
# - Filter and preprocess a dataset of restaurants.
# - Encode categorical variables for better handling in our recommendation system.
# - Provide options for users to select their country, city, and preferred cuisine.
# - Display the top restaurant recommendations along with their ratings and votes.
# - Visualize the restaurant locations on a map using Folium.
#
# This task aims to create an interactive experience for users, enabling them to find suitable dining options based on their preferences effectively.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Step 1: Import Libraries and Load Dataset
#
# In this step, we will import the required libraries, install Folium for map visualization, and load the restaurant dataset.
#
# ```python
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# # Install Folium for map visualization
# !pip install folium
#
# # Load the restaurant dataset
# df = pd.read_csv("/content/drive/MyDrive/Internship/Dataset.csv")
# df.head()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.10/dist-packages (0.17.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium) (0.8.0)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium) (3.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from folium) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.10/dist-packages (from folium) (2024.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2024.8.30)

# %%
df=pd.read_csv("/content/drive/MyDrive/Internship/Dataset.csv")
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# 3      SM Megamall, Ortigas, Mandaluyong City
# 4      SM Megamall, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831  14.581404
# 3  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475  14.585318
# 4  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508  14.584450
#
#                            Cuisines  ...          Currency Has Table booking  \
# 0        French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
# 1                          Japanese  ...  Botswana Pula(P)               Yes
# 2  Seafood, Asian, Filipino, Indian  ...  Botswana Pula(P)               Yes
# 3                   Japanese, Sushi  ...  Botswana Pula(P)                No
# 4                  Japanese, Korean  ...  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
# 1                  No                No                   No           3
# 2                  No                No                   No           4
# 3                  No                No                   No           4
# 4                  No                No                   No           4
#
#    Aggregate rating  Rating color Rating text Votes
# 0               4.8    Dark Green   Excellent   314
# 1               4.5    Dark Green   Excellent   591
# 2               4.4         Green   Very Good   270
# 3               4.9    Dark Green   Excellent   365
# 4               4.8    Dark Green   Excellent   229
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Step 2: Data Cleaning
#
# In this step, we will clean the dataset to ensure that our restaurant recommendation system operates effectively. This involves the following tasks:
#
# 1. **Checking for Missing Values**:
#    We will check for any missing values (NaN) in the dataset. Missing values can lead to inaccuracies in our recommendations, so it's important to address them.
#
# 2. **Removing Rows with Missing Values**:
#    After identifying columns with missing values, we will remove any rows that contain these NaN values. This ensures that our dataset is complete and ready for analysis.
#
# 3. **Checking for Duplicate Entries**:
#    Duplicates can skew the results of our recommendation system. We will check for any duplicate rows in the dataset to maintain data integrity.
#
# 4. **Removing Duplicate Rows**:
#    If any duplicates are found, we will remove them from the dataset. This step is crucial to avoid bias in our recommendations.
#
# 5. **Displaying the Cleaned Dataset**:
#    Finally, we will display the first few rows of the cleaned dataset to verify that the data has been processed correctly.

# %%
# Print the columns of the DataFrame
print(df.columns)
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# dtype: object

# %% [markdown]
# ## Step 2: Data Cleaning - Handling Missing Values
#
# In this step, we focus on cleaning the dataset by handling missing values, which is a crucial part of data preprocessing.
#
# - **Checking for null values**: We first check for any missing (null) values in each column using `isnull().sum()`. This will give us a quick overview of the extent of missing data in the dataset.
#
# - **Dropping columns with null values**: If any columns have missing values, we choose to drop them using the `dropna()` function. This ensures that the data we work with is clean and free from incomplete information.
#
# Finally, we display the remaining columns to verify that the dataset is ready for further analysis.

# %%
df= df.drop_duplicates(subset=['Latitude', 'Longitude'], keep=False)

# %%
# Check for total null values in each column
null_values = df.isnull().sum()

# Display the total null values for each column
print(null_values)
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
# Drop columns with null values
df = df.dropna(axis=0, how='any')

# Display the remaining columns
print(df.columns)
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
# Check for total null values in each column
null_values = df.isnull().sum()

# Display the total null values for each column
print(null_values)
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %% [markdown]
# ## Step 3: Dropping Unnecessary Columns
#
# In this step, we will remove columns from the dataset that are not relevant to our restaurant recommendation system. This helps simplify the dataset and focus on the most important features that will influence recommendations.
#
# ### Columns to be Dropped:
# - **Restaurant ID**: This is a unique identifier for each restaurant, which does not contribute to our analysis.
# - **Restaurant Name**: While it identifies the restaurant, it’s not necessary for the recommendation logic.
# - **Address**: The full address is not required as we will use latitude and longitude for mapping.
# - **Locality**: This column is redundant after the removal of "Locality Verbose."
# - **Currency**: This is not directly relevant to our recommendation criteria.
# - **Rating Color**: This does not provide useful information for recommendations.
# - **Switch to order menu**: This is not necessary for the recommendation system.
# - **Has Table Booking**: We might not focus on this criterion in our initial recommendation.

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
# Dropping unnecessary columns
df = df.drop(columns=['Restaurant ID', 'Address', 'Locality', 'Locality Verbose', 'Currency', 'Switch to order menu'])
df.head()
# Out:
#           Restaurant Name  Country Code              City   Longitude  \
# 0        Le Petit Souffle           162       Makati City  121.027535
# 1        Izakaya Kikufuji           162       Makati City  121.014101
# 2  Heat - Edsa Shangri-La           162  Mandaluyong City  121.056831
# 3                    Ooma           162  Mandaluyong City  121.056475
# 4             Sambo Kojin           162  Mandaluyong City  121.057508
#
#     Latitude                          Cuisines  Average Cost for two  \
# 0  14.565443        French, Japanese, Desserts                  1100
# 1  14.553708                          Japanese                  1200
# 2  14.581404  Seafood, Asian, Filipino, Indian                  4000
# 3  14.585318                   Japanese, Sushi                  1500
# 4  14.584450                  Japanese, Korean                  1500
#
#   Has Table booking Has Online delivery Is delivering now  Price range  \
# 0               Yes                  No                No            3
# 1               Yes                  No                No            3
# 2               Yes                  No                No            4
# 3                No                  No                No            4
# 4               Yes                  No                No            4
#
#    Aggregate rating Rating color Rating text  Votes
# 0               4.8   Dark Green   Excellent    314
# 1               4.5   Dark Green   Excellent    591
# 2               4.4        Green   Very Good    270
# 3               4.9   Dark Green   Excellent    365
# 4               4.8   Dark Green   Excellent    229

# %%
# Drop the Rating color column
df = df.drop(columns=['Rating color'])

# Check the remaining columns
print(df.columns)
# Out:
# Index(['Restaurant Name', 'Country Code', 'City', 'Longitude', 'Latitude',
#        'Cuisines', 'Average Cost for two', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Price range',
#        'Aggregate rating', 'Rating text', 'Votes'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Restaurant Name          object
# Country Code              int64
# City                     object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Price range               int64
# Aggregate rating        float64
# Rating text              object
# Votes                     int64
# dtype: object

# %%
# Convert Yes/No columns to 1/0
df['Has Table booking'] = df['Has Table booking'].replace({'Yes': 1, 'No': 0})
df['Has Online delivery'] = df['Has Online delivery'].replace({'Yes': 1, 'No': 0})
df['Is delivering now'] = df['Is delivering now'].replace({'Yes': 1, 'No': 0})

# Check the resulting DataFrame
df.head()
# Out:
# <ipython-input-124-31668029527b>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Has Table booking'] = df['Has Table booking'].replace({'Yes': 1, 'No': 0})
# <ipython-input-124-31668029527b>:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Has Online delivery'] = df['Has Online delivery'].replace({'Yes': 1, 'No': 0})
# <ipython-input-124-31668029527b>:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Is delivering now'] = df['Is delivering now'].replace({'Yes': 1, 'No': 0})
#           Restaurant Name  Country Code              City   Longitude  \
# 0        Le Petit Souffle           162       Makati City  121.027535
# 1        Izakaya Kikufuji           162       Makati City  121.014101
# 2  Heat - Edsa Shangri-La           162  Mandaluyong City  121.056831
# 3                    Ooma           162  Mandaluyong City  121.056475
# 4             Sambo Kojin           162  Mandaluyong City  121.057508
#
#     Latitude                          Cuisines  Average Cost for two  \
# 0  14.565443        French, Japanese, Desserts                  1100
# 1  14.553708                          Japanese                  1200
# 2  14.581404  Seafood, Asian, Filipino, Indian                  4000
# 3  14.585318                   Japanese, Sushi                  1500
# 4  14.584450                  Japanese, Korean                  1500
#
#    Has Table booking  Has Online delivery  Is delivering now  Price range  \
# 0                  1                    0                  0            3
# 1                  1                    0                  0            3
# 2                  1                    0                  0            4
# 3                  0                    0                  0            4
# 4                  1                    0                  0            4
#
#    Aggregate rating Rating text  Votes
# 0               4.8   Excellent    314
# 1               4.5   Excellent    591
# 2               4.4   Very Good    270
# 3               4.9   Excellent    365
# 4               4.8   Excellent    229

# %%
df.shape
# Out:
# (8467, 14)

# %% [markdown]
# ## Step 5: Function to Get User Preferences
#
# In this step, we will create a function named `get_user_preferences(df)` that will interactively ask the user to select their preferences for the restaurant recommendation system. This function will guide the user through the selection process of the country, city, and cuisine.
#
# ### Function Explanation
#
# **Function Name**: `get_user_preferences(df)`
#
# **Parameters**:
# - `df`: The DataFrame containing the restaurant dataset.
#
# ### Function Steps:
# 1. **Display Available Countries**:
#    - The function first retrieves the unique country codes from the DataFrame.
#    - It prints a list of available country codes for the user to choose from, indexed for easy selection.
#
# 2. **User Selects Country**:
#    - The user is prompted to enter the index of their preferred country code.
#    - The selected country code is then stored for filtering subsequent options.
#
# 3. **Filter Cities Based on Country**:
#    - The function filters the DataFrame to find cities that belong to the selected country.
#    - It displays the available cities for the user to choose from, again indexed for easy selection.
#
# 4. **User Selects City**:
#    - The user inputs the index corresponding to their preferred city.
#    - The selected city is stored for further filtering.
#
# 5. **Filter Cuisines Based on City**:
#    - The function then filters the DataFrame again to find unique cuisines available in the selected city.
#    - It displays these cuisines to the user in a numbered list.
#
# 6. **User Selects Cuisine**:
#    - The user selects their desired cuisine by entering the corresponding index.
#    - The selected cuisine is returned alongside the selected city and country code.
#
# ### Return Value:
# The function returns three values: `selected_cuisine`, `selected_city`, and `selected_country`, which can be used to filter the restaurant dataset for recommendations.

# %%
def get_user_preferences(df):
    # Print available country codes and names
    print("Available Countries:")
    country_options = df['Country Code'].unique()
    for idx, code in enumerate(country_options):
        print(f"{idx}: {code}")  # Display country code options

    # User selects country code
    country_selection = int(input("Select a country code (enter index): "))
    selected_country = country_options[country_selection]

    # Filter cities based on the selected country
    cities_in_country = df[df['Country Code'] == selected_country]['City'].unique()
    print(f"\nAvailable Cities in {selected_country}:")
    for idx, city in enumerate(cities_in_country):
        print(f"{idx}: {city}")  # Display city options

    city_selection = int(input("Select a city (enter index): "))
    selected_city = cities_in_country[city_selection]

    # Filter cuisines based on the selected city
    cuisines_in_city = df[df['City'] == selected_city]['Cuisines'].unique()
    print(f"\nAvailable Cuisines in {selected_city}:")
    for idx, cuisine in enumerate(cuisines_in_city):
        print(f"{idx}: {cuisine}")  # Display cuisine options

    cuisine_selection = int(input("Select a cuisine (enter index): "))
    selected_cuisine = cuisines_in_city[cuisine_selection]

    return selected_cuisine, selected_city, selected_country

# %% [markdown]
# ## Step 6: Function to Filter Restaurants
#
# In this step, we will create a function named `filter_restaurants(df, cuisine, city)` that filters the restaurant dataset based on the user's selected cuisine and city. This function is crucial for narrowing down the list of restaurants to only those that match the user's preferences.
#
# ### Function Explanation
#
# **Function Name**: `filter_restaurants(df, cuisine, city)`
#
# **Parameters**:
# - `df`: The DataFrame containing the restaurant dataset.
# - `cuisine`: The cuisine type selected by the user.
# - `city`: The city selected by the user.
#
# ### Function Steps:
# 1. **Filtering the DataFrame**:
#    - The function uses boolean indexing to filter the DataFrame `df`.
#    - It checks two conditions:
#      - The `Cuisines` column must match the selected `cuisine`.
#      - The `City` column must match the selected `city`.
#    - Both conditions are combined using the `&` operator to ensure that only restaurants that meet both criteria are included.
#
# 2. **Return Value**:
#    - The function returns a new DataFrame, `filtered_df`, which contains only the restaurants that match the user's selected cuisine and city.

# %%
# Step 2: Filter the dataset based on user input
def filter_restaurants(df, cuisine, city):
    filtered_df = df[
        (df['Cuisines'] == cuisine) &
        (df['City'] == city)
    ]
    return filtered_df

# %% [markdown]
# ## Step 7: Function to Display Top Restaurants
#
# In this step, we will create a function named `display_top_restaurants(filtered_df)` that displays the top five restaurants based on the user's selected criteria. This function will provide valuable insights into the best dining options available.
#
# ### Function Explanation
#
# **Function Name**: `display_top_restaurants(filtered_df)`
#
# **Parameters**:
# - `filtered_df`: A DataFrame containing the filtered restaurant data based on the user’s selected cuisine and city.
#
# ### Function Steps:
# 1. **Check for Empty DataFrame**:
#    - The function first checks if `filtered_df` is empty.
#    - If it is empty, a message indicating that no restaurants were found is printed, and the function exits early.
#
# 2. **Sorting the DataFrame**:
#    - If the DataFrame is not empty, the function sorts the restaurants based on two criteria:
#      - `Aggregate rating`: To prioritize higher-rated restaurants.
#      - `Votes`: To consider the number of votes as an indicator of popularity.
#    - The function uses `nlargest(5, ['Aggregate rating', 'Votes'])` to retrieve the top five restaurants.
#
# 3. **Displaying Restaurant Details**:
#    - The function iterates through the top five restaurants and prints relevant details for each:
#      - Restaurant Name
#      - Rating
#      - Votes
#      - Location (latitude and longitude)
#    - A separator line is printed between each restaurant's details for better readability.

# %%
# Step 3: Sort and display the top five restaurants
def display_top_restaurants(filtered_df):
    if filtered_df.empty:
        print("No restaurants found matching your criteria.")
        return

    # Sort by Aggregate Rating and Votes
    top_restaurants = filtered_df.nlargest(5, ['Aggregate rating', 'Votes'])

    for idx, row in top_restaurants.iterrows():
        print(f"Restaurant Name: {row['Restaurant Name']}")
        print(f"Rating: {row['Aggregate rating']}")
        print(f"Votes: {row['Votes']}")
        print(f"Location: {row['Latitude']}, {row['Longitude']}")
        print("------------------------------")

# %% [markdown]
# ## Step 8: Function to Visualize Restaurants on a Map
#
# In this step, we will create a function named `visualize_restaurants_on_map(filtered_df)` that allows users to see the top restaurants on a map. This visualization provides a geographical context to the restaurant options, making it easier for users to locate them.
#
# ### Function Explanation
#
# **Function Name**: `visualize_restaurants_on_map(filtered_df)`
#
# **Parameters**:
# - `filtered_df`: A DataFrame containing the filtered restaurant data based on the user’s selected cuisine and city.
#
# ### Function Steps:
# 1. **Check for Empty DataFrame**:
#    - The function first checks if `filtered_df` is empty.
#    - If it is empty, a message indicating that no restaurants are available to display on the map is printed, and the function exits early.
#
# 2. **Create a Base Map**:
#    - If the DataFrame is not empty, the function creates a base map using the Folium library.
#    - The map is centered around the average latitude and longitude of the restaurants in `filtered_df`, with an initial zoom level of 12.
#
# 3. **Adding Markers for Each Restaurant**:
#    - The function iterates through each restaurant in `filtered_df`.
#    - For each restaurant, a marker is added to the map at its corresponding latitude and longitude.
#    - Each marker includes a popup that displays:
#      - Restaurant Name
#      - Rating
#      - Votes
#    - The markers are colored blue for visibility.
#
# 4. **Return the Map**:
#    - Finally, the function returns the created map object for visualization.

# %%
# Function to visualize top restaurants on a map
def visualize_restaurants_on_map(filtered_df):
    if filtered_df.empty:
        print("No restaurants found to display on the map.")
        return

    # Create a base map centered around the first restaurant's location
    m = folium.Map(location=[filtered_df['Latitude'].mean(), filtered_df['Longitude'].mean()], zoom_start=12)

    # Add markers for each restaurant
    for idx, row in filtered_df.iterrows():
        folium.Marker(
            location=[row['Latitude'], row['Longitude']],
            popup=f"{row['Restaurant Name']}<br>Rating: {row['Aggregate rating']}<br>Votes: {row['Votes']}",
            icon=folium.Icon(color='blue')
        ).add_to(m)

    # Display the map
    return m

# %% [markdown]
# ## Step 9: Main Flow for User Interaction and Visualization
#
# In this final step, we will create the main flow of the application that allows users to select their preferences for country, city, and cuisine. Based on the user’s input, the program will filter the dataset, display the top restaurants, and visualize them on a map.

# %%
# Main flow with country, city, cuisine selection and map visualization
selected_cuisine, selected_city, selected_country = get_user_preferences(df)
if selected_cuisine and selected_city:
    filtered_restaurants = filter_restaurants(df, selected_cuisine, selected_city)
    display_top_restaurants(filtered_restaurants)

    # Visualize the top restaurants on the map
    restaurant_map = visualize_restaurants_on_map(filtered_restaurants)
    display(restaurant_map)  # Use display() to visualize the map
# Out:
# Available Countries:
# 0: 162
# 1: 30
# 2: 216
# 3: 14
# 4: 37
# 5: 184
# 6: 214
# 7: 1
# 8: 94
# 9: 148
# 10: 215
# 11: 166
# 12: 189
# 13: 191
# 14: 208
# Select a country code (enter index): 7
#
# Available Cities in 1:
# 0: Agra
# 1: Ahmedabad
# 2: Allahabad
# 3: Amritsar
# 4: Aurangabad
# 5: Bangalore
# 6: Bhopal
# 7: Bhubaneshwar
# 8: Chandigarh
# 9: Chennai
# 10: Coimbatore
# 11: Dehradun
# 12: Faridabad
# 13: Ghaziabad
# 14: Goa
# 15: Gurgaon
# 16: Guwahati
# 17: Hyderabad
# 18: Indore
# 19: Jaipur
# 20: Kanpur
# 21: Kochi
# 22: Kolkata
# 23: Lucknow
# 24: Ludhiana
# 25: Mangalore
# 26: Mohali
# 27: Mumbai
# 28: Mysore
# 29: Nagpur
# 30: Nashik
# 31: New Delhi
# 32: Noida
# 33: Panchkula
# 34: Patna
# 35: Puducherry
# 36: Pune
# 37: Ranchi
# 38: Secunderabad
# 39: Surat
# 40: Vadodara
# 41: Varanasi
# 42: Vizag
# Select a city (enter index): 31
#
# Available Cuisines in New Delhi:
# 0: Fast Food
# 1: North Indian, Seafood, Continental
# 2: South Indian, North Indian
# 3: South Indian, North Indian, Chinese
# 4: Mughlai
# 5: South Indian
# 6: Pizza
# 7: North Indian, Chinese
# 8: Chinese, North Indian
# 9: Mediterranean, Italian
# 10: Continental, Seafood, Goan, Andhra, Kerala, Thai
# 11: Parsi
# 12: Finger Food
# 13: North Indian, Mughlai
# 14: Pizza, Fast Food
# 15: North Indian, Chinese, Continental
# 16: North Indian, Continental, Chinese
# 17: Street Food, Mithai
# 18: Street Food, South Indian, Mithai
# 19: Italian, Pizza, Fast Food
# 20: Bakery, Fast Food
# 21: North Indian, Fast Food
# 22: Mithai, North Indian, South Indian, Street Food
# 23: Mithai, Street Food
# 24: Cafe
# 25: Raw Meats, North Indian, Fast Food
# 26: Chinese, North Indian, Italian, Mughlai
# 27: Chinese
# 28: Chinese, Thai
# 29: Street Food, Fast Food, Beverages
# 30: Desserts, Ice Cream
# 31: North Indian
# 32: North Indian, South Indian, Chinese
# 33: Bakery, Desserts
# 34: North Indian, Biryani
# 35: Bengali
# 36: Ice Cream, Desserts
# 37: Chinese, Mughlai, North Indian
# 38: Ice Cream
# 39: Raw Meats, Fast Food
# 40: Chinese, North Indian, Mughlai, Pizza
# 41: Turkish
# 42: Pizza, Italian
# 43: Burger, Fast Food
# 44: Asian, Chinese
# 45: American
# 46: Continental, Chinese, North Indian
# 47: Chinese, Japanese, Thai, Malaysian, Vietnamese, Asian
# 48: North Indian, South Indian
# 49: North Indian, Street Food, Mughlai
# 50: Cafe, Desserts
# 51: Seafood, South Indian, Andhra, Hyderabadi, Goan
# 52: Chinese, Fast Food, North Indian, South Indian
# 53: Italian, Continental, Cafe
# 54: Fast Food, North Indian, Chinese, Desserts
# 55: Chinese, Fast Food
# 56: Street Food
# 57: Cafe, North Indian, Fast Food
# 58: Chinese, South Indian
# 59: Fast Food, North Indian, Chinese
# 60: Mughlai, North Indian
# 61: Healthy Food
# 62: Chinese, North Indian, Italian
# 63: Bakery, Desserts, Fast Food, Pizza, Burger, Continental
# 64: North Indian, Chinese, South Indian, Fast Food
# 65: Desserts, Bakery, Pizza, Burger, Continental
# 66: Cafe, Bakery
# 67: Bakery, Desserts, Fast Food, Mithai
# 68: Fast Food, Beverages
# 69: Bakery
# 70: Chinese, South Indian, North Indian
# 71: South Indian, Chinese
# 72: Italian, Fast Food
# 73: North Indian, European
# 74: Fast Food, Burger
# 75: Continental, Asian, North Indian
# 76: Japanese, Korean
# 77: Continental
# 78: Malaysian, Indonesian
# 79: Japanese, Asian
# 80: Continental, North Indian, Mughlai, Italian
# 81: North Indian, South Indian, Chinese, Mithai, Fast Food
# 82: Beverages, Fast Food
# 83: North Indian, Street Food
# 84: North Indian, South Indian, Chinese, Fast Food, Mithai
# 85: North Indian, Mughlai, Chinese
# 86: Raw Meats, Fast Food, North Indian
# 87: North Indian, Chinese, Mughlai
# 88: Bakery, Desserts, Fast Food
# 89: Bakery, Desserts, Chinese, Fast Food
# 90: Fast Food, Chinese, Bakery
# 91: Mithai
# 92: Beverages
# 93: Bakery, Chinese
# 94: Fast Food, Chinese
# 95: Street Food, Chinese, North Indian, Mithai
# 96: North Indian, Chinese, Fast Food
# 97: Chinese, Italian, North Indian
# 98: North Indian, Mughlai, Chinese, Continental
# 99: North Indian, Mughlai, Chinese, Italian
# 100: Pizza, Fast Food, Chinese
# 101: North Indian, South Indian, Street Food
# 102: Fast Food, Italian, Chinese
# 103: North Indian, South Indian, Chinese, Street Food, Mithai
# 104: Bakery, Mithai
# 105: North Indian, South Indian, Street Food, Mithai
# 106: North Indian, Street Food, Chinese, South Indian, Mithai
# 107: Bengali, North Indian, Chinese
# 108: Lebanese, Arabian, Moroccan
# 109: Fast Food, North Indian
# 110: Japanese, Chinese, Malaysian, Thai, Vietnamese
# 111: Lebanese
# 112: Chinese, Thai, North Indian
# 113: Burger, Desserts, Fast Food
# 114: Chinese, Japanese, Thai
# 115: Mithai, North Indian
# 116: Fast Food, North Indian, Desserts, Ice Cream
# 117: Bakery, Italian, Fast Food, Chinese, Continental
# 118: North Indian, South Indian, Fast Food, Street Food, Chinese, Beverages, Desserts, Mithai
# 119: Chinese, North Indian, Seafood
# 120: Kashmiri, North Indian
# 121: Cafe, Healthy Food, North Indian
# 122: Gujarati, South Indian, North Indian
# 123: Assamese, Chinese
# 124: North Eastern
# 125: South Indian, Chinese, Fast Food
# 126: Mithai, Fast Food
# 127: North Indian, South Indian, Fast Food, Street Food, Chinese, Desserts, Mithai
# 128: North Indian, Fast Food, Chinese, South Indian
# 129: North Indian, Street Food, Chinese, South Indian
# 130: Beverages, Street Food
# 131: Desserts
# 132: Mughlai, Biryani
# 133: North Indian, South Indian, Chinese, Street Food, Fast Food, Mithai, Desserts
# 134: Street Food, North Indian, South Indian, Mithai
# 135: Ice Cream, Mithai, North Indian, Street Food
# 136: Mughlai, Street Food
# 137: Desserts, Street Food
# 138: Street Food, Beverages
# 139: Mithai, Bakery
# 140: North Indian, Mughlai, Fast Food, South Indian
# 141: North Indian, Mughlai, Biryani
# 142: Mughlai, North Indian, Bengali, Continental
# 143: Mughlai, North Indian, Chinese
# 144: North Indian, Chinese, Biryani
# 145: Continental, American, Fast Food
# 146: Bengali, North Indian
# 147: North Indian, Mughlai, Biryani, Bengali
# 148: Biryani, North Indian
# 149: Continental, North Indian, Chinese
# 150: North Indian, Italian, Fast Food
# 151: North Indian, Chinese, Continental, Italian
# 152: Chinese, North Indian, Mughlai
# 153: Cafe, Italian, Continental
# 154: Gujarati
# 155: Biryani, Mughlai
# 156: Chinese, Japanese, Korean, Asian
# 157: Chinese, North Indian, Street Food
# 158: North Indian, Street Food, Mithai
# 159: Italian, Tex-Mex, Continental, North Indian
# 160: North Indian, Lucknowi
# 161: North Indian, Continental, Italian
# 162: Finger Food, Continental, North Indian, Chinese
# 163: North Indian, Chinese, Italian, Continental
# 164: North Indian, Italian, Continental
# 165: Continental, Italian, Asian, Indian
# 166: Continental, Mexican, American, Italian, North Indian
# 167: Burger, Juices, Finger Food
# 168: Chinese, Continental, North Indian
# 169: North Indian, Chinese, Italian, Mediterranean
# 170: Pizza, Italian, Cafe
# 171: Cafe, Tea
# 172: Asian, Japanese, Chinese, Thai
# 173: North Indian, Continental, European
# 174: North Indian, Mexican, Italian, Continental
# 175: Healthy Food, Beverages
# 176: Street Food, North Indian, South Indian, Chinese, Mithai
# 177: North Indian, Continental
# 178: North Indian, Continental, Chinese, Italian, Thai, Mughlai
# 179: American, Fast Food
# 180: North Indian, Italian, Mexican, Chettinad, Chinese, Lebanese
# 181: Goan, Seafood
# 182: Cafe, North Indian, Italian, Japanese, Fast Food
# 183: European, Chinese, North Indian, Italian
# 184: Arabian, Mexican
# 185: Bengali, South Indian, North Indian, Mughlai
# 186: Portuguese, African
# 187: North Indian, Italian, Chinese, Mexican
# 188: North Indian, Chinese, Mughlai, Italian
# 189: Chinese, Italian, Continental, North Indian
# 190: Finger Food, European, North Indian
# 191: Gujarati, Rajasthani
# 192: Continental, American, Tex-Mex, North Indian
# 193: American, Fast Food, Salad, Healthy Food
# 194: Finger Food, North Indian, Continental, Italian
# 195: North Indian, Continental, Finger Food
# 196: Finger Food, North Indian, Italian
# 197: Italian, Mediterranean, Continental, North Indian
# 198: North Indian, Mediterranean, Asian
# 199: North Indian, Continental, Fast Food
# 200: North Indian, Mediterranean, Asian, Continental
# 201: American, Continental, Italian, North Indian, Asian
# 202: Chinese, Japanese, Italian, Seafood
# 203: Lebanese, Mediterranean, Middle Eastern, Arabian
# 204: Tea
# 205: North Indian, Italian, Asian, American
# 206: Biryani, North Indian, Hyderabadi
# 207: Biryani, Hyderabadi
# 208: North Indian, Chinese, Italian, American, Middle Eastern
# 209: Continental, North Indian, Chinese, Mediterranean
# 210: Modern Indian
# 211: Japanese
# 212: Healthy Food, Continental, Italian
# 213: North Indian, Mediterranean, Asian, Fast Food
# 214: Continental, Mediterranean, Italian, North Indian
# 215: Fast Food, American, Burger
# 216: Continental, American, Asian, North Indian
# 217: Italian, Mexican, Continental, North Indian, Finger Food
# 218: Continental, Mexican, Burger, American, Pizza, Tex-Mex
# 219: North Indian, Afghani, Mughlai
# 220: Continental, North Indian, Italian, Asian
# 221: North Indian, European, Asian, Mediterranean
# 222: Bakery, Fast Food, Desserts
# 223: Continental, Italian
# 224: Italian, North Indian, Continental
# 225: North Indian, Chinese, Finger Food
# 226: North Indian, South Indian, Chinese, Fast Food
# 227: North Indian, Chinese, Fast Food, South Indian
# 228: Chinese, Japanese
# 229: Fast Food, Street Food
# 230: North Indian, Bengali
# 231: Italian
# 232: Lebanese, Arabian
# 233: Cafe, Italian, Chinese
# 234: Mughlai, Fast Food
# 235: Biryani, North Indian, Mughlai
# 236: North Indian, Continental, Chinese, Italian
# 237: Italian, Pizza
# 238: Biryani
# 239: Italian, French
# 240: Cafe, Healthy Food, Continental
# 241: Rajasthani
# 242: North Indian, Chinese, South Indian
# 243: South Indian, Chinese, Continental
# 244: North Indian, South Indian, Chinese, Street Food, Fast Food
# 245: North Indian, Fast Food, Chinese
# 246: Korean
# 247: Chinese, Beverages
# 248: Cafe, Continental, Chinese, Italian
# 249: North Indian, Chinese, Cafe
# 250: North Indian, Continental, Chinese, Italian, Lebanese
# 251: Chinese, North Indian, Fast Food, Italian
# 252: Cafe, Chinese, Italian
# 253: Cafe, Fast Food, Italian, Chinese
# 254: Fast Food, Italian
# 255: Italian, Pizza, Bakery
# 256: Ice Cream, Desserts, Beverages
# 257: Cafe, Mexican, American, Italian, Lebanese, Continental
# 258: Goan
# 259: Oriya
# 260: Kashmiri
# 261: Chinese, North Indian, Fast Food
# 262: Maharashtrian
# 263: Chinese, Naga
# 264: Chinese, Tibetan
# 265: Fast Food, North Indian, South Indian, Chinese
# 266: Mughlai, Chinese
# 267: Mexican, North Indian, European, Chinese, Italian
# 268: Cafe, Continental
# 269: Thai, Chinese, Asian, Malaysian
# 270: Middle Eastern, Mediterranean, North Indian
# 271: Bakery, Italian, Chinese, Mexican
# 272: American, Tex-Mex
# 273: Italian, Continental, European, Cafe
# 274: Desserts, Cafe
# 275: Desserts, Beverages
# 276: American, Fast Food, Desserts
# 277: North Indian, Italian, Chinese, Fast Food
# 278: Bihari
# 279: Afghani, Mughlai, Chinese
# 280: North Indian, Mithai
# 281: Fast Food, Pizza
# 282: Street Food, Chinese
# 283: Chinese, Lucknowi
# 284: Chinese, Thai, Asian, Malaysian, Vietnamese, Japanese
# 285: North Indian, Mughlai, Chinese, Seafood
# 286: Fast Food, Cafe
# 287: North Indian, Mughlai, Continental
# 288: Chinese, Cafe, Fast Food
# 289: Continental, Chinese, North Indian, Healthy Food
# 290: Chinese, Seafood
# 291: Continental, Healthy Food
# 292: Chinese, Thai, Seafood
# 293: North Indian, Fast Food, Mughlai
# 294: Healthy Food, Fast Food
# 295: Chinese, Thai, Asian
# 296: European, Italian, North Indian
# 297: Finger Food, Italian, North Indian
# 298: North Indian, Chinese, Continental, Seafood
# 299: Mediterranean, Continental, Italian
# 300: South Indian, Andhra
# 301: Ice Cream, Fast Food, Beverages
# 302: European, Sushi, Italian
# 303: Chinese, South Indian, Fast Food
# 304: North Indian, Fast Food, Continental
# 305: Kashmiri, Chinese, Mughlai
# 306: Chinese, Healthy Food
# 307: Burger, American, Fast Food, Italian, Pizza
# 308: Burger, American, Fast Food
# 309: European, Italian
# 310: Cafe, Italian, Lebanese
# 311: Healthy Food, Continental
# 312: North Indian, Continental, Italian, Finger Food
# 313: Fast Food, American, Italian
# 314: Mexican, Italian, American
# 315: British, Chinese, Italian
# 316: Burmese, Chinese, Japanese, Malaysian, Thai
# 317: Thai
# 318: Continental, North Indian, Asian
# 319: Continental, Chinese, Thai
# 320: European, Asian, North Indian, Italian, Continental, Pizza
# 321: Asian, Chinese, Thai
# 322: Nepalese
# 323: Chinese, Thai, Japanese
# 324: Asian
# 325: Cafe, Italian, Continental, Fast Food
# 326: Desserts, Fast Food
# 327: Cafe, Fast Food, Continental
# 328: Bakery, Desserts, Ice Cream
# 329: North Indian, Italian, Chinese
# 330: Chinese, Thai, Fast Food
# 331: American, Italian, Mughlai, North Indian
# 332: Chinese, Asian, Thai
# 333: Healthy Food, Continental, Juices, Salad
# 334: North Indian, Chinese, South Indian, Seafood, Chettinad
# 335: Mexican
# 336: Continental, North Indian, Italian
# 337: Tibetan, Nepalese
# 338: Lebanese, Chinese, Fast Food
# 339: Turkish, Mediterranean, Middle Eastern
# 340: Sushi
# 341: North Indian, Mediterranean, Continental
# 342: Italian, North Indian
# 343: South Indian, North Indian, Street Food, Chinese, Mithai
# 344: Chinese, Seafood, Thai
# 345: South Indian, North Indian, Chinese, Fast Food, Street Food, Mithai
# 346: Chinese, Thai, Seafood, Naga
# 347: Tea, Fast Food
# 348: Juices
# 349: Mithai, Street Food, Fast Food
# 350: Healthy Food, Juices, Salad
# 351: North Indian, Finger Food
# 352: Fast Food, Street Food, Beverages
# 353: Cafe, Fast Food, Italian
# 354: Mithai, Street Food, North Indian, South Indian, Chinese, Fast Food, Beverages
# 355: Street Food, Fast Food
# 356: Beverages, Desserts
# 357: European, Continental
# 358: North Indian, Biryani, Mughlai
# 359: Cafe, Fast Food, North Indian
# 360: Naga
# 361: Continental, Cafe
# 362: South Indian, Kerala
# 363: North Indian, Continental, Asian, Italian
# 364: Cafe, Mexican, Continental
# 365: Vietnamese
# 366: Italian, Continental
# 367: Continental, American, Italian
# 368: North Indian, Italian, Continental, Chinese
# 369: Continental, Kerala
# 370: Continental, American, Italian, Bakery
# 371: Continental, Asian, Italian, Mediterranean, Burger
# 372: American, Continental, North Indian, Chinese
# 373: Mediterranean, Italian, Continental, Spanish, North Indian
# 374: Continental, Tex-Mex
# 375: North Indian, Chinese, Thai, Italian, Middle Eastern
# 376: American, North Indian, European, Asian
# 377: American, British, Continental
# 378: European, Italian, Cafe
# 379: Continental, Chinese, Thai, Mediterranean
# 380: Japanese, Chinese, Asian, Thai
# 381: North Indian, Kashmiri, Chinese, Thai, Korean
# 382: Finger Food, North Indian, Chinese
# 383: North Indian, Continental, South Indian, Chinese
# 384: Finger Food, Italian
# 385: North Indian, Mughlai, Chinese, South Indian
# 386: Kerala, Biryani
# 387: South Indian, North Indian, Chinese, Mughlai
# 388: North Indian, Maharashtrian
# 389: Fast Food, Desserts
# 390: Mithai, South Indian, Street Food
# 391: Kerala, South Indian
# 392: North Indian, Chinese, South Indian, Street Food, Mithai
# 393: Drinks Only
# 394: Asian, Japanese, Korean, Thai, Chinese
# 395: Hyderabadi
# 396: Chinese, Mexican, Italian
# 397: Chinese, Mithai
# 398: Continental, North Indian, Mughlai, Chinese
# 399: North Indian, South Indian, Chinese, Street Food
# 400: North Indian, South Indian, Street Food, Fast Food, Mithai
# 401: Chinese, Mughlai
# 402: North Indian, Chinese, Continental, Fast Food
# 403: North Indian, Fast Food, Italian, Asian
# 404: Chinese, North Indian, Thai
# 405: Italian, Chinese, Fast Food, North Indian
# 406: Mughlai, Afghani
# 407: North Indian, Mughlai, South Indian
# 408: North Indian, Afghani
# 409: Afghani
# 410: South Indian, Street Food, Chinese
# 411: Cafe, European
# 412: Modern Indian, North Indian
# 413: Cafe, Desserts, Healthy Food, Juices
# 414: Italian, Mediterranean
# 415: North Indian, Spanish, Mediterranean
# 416: North Indian, Lebanese, European, Mexican
# 417: Finger Food, North Indian
# 418: American, Italian, North Indian, European, Thai
# 419: North Indian, Italian, Continental, Asian
# 420: North Indian, American, Chinese
# 421: Continental, North Indian, Chinese, Mughlai, Asian
# 422: Continental, North Indian, Chinese, Cafe
# 423: Italian, Mexican, Lebanese, Continental
# 424: European, Continental, North Indian
# 425: Healthy Food, Salad
# 426: North Indian, South Indian, Chinese, Fast Food, Bakery, Mithai
# 427: Bakery, Desserts, Fast Food, Beverages
# 428: Continental, Chinese, Italian, Finger Food
# 429: North Indian, South Indian, Chinese, Mithai
# 430: Thai, Chinese, Seafood
# 431: Street Food, North Indian, South Indian
# 432: Fast Food, Italian, North Indian, Chinese
# 433: Cafe, North Indian, Lebanese, Continental
# 434: Italian, Chinese, Continental, Thai, Mediterranean, Lebanese
# 435: Ice Cream, Desserts, North Indian, Street Food
# 436: Street Food, North Indian, Mithai
# 437: Cafe, Fast Food, Desserts
# 438: Chinese, North Indian, Italian, Continental, Fast Food
# 439: Cafe, Chinese, Continental, Italian, Desserts, Beverages
# 440: Mithai, Chinese, Street Food
# 441: Street Food, North Indian
# 442: North Indian, Biryani, Chinese, Fast Food
# 443: Chinese, North Indian, Italian, Fast Food
# 444: North Indian, Chinese, Italian
# 445: Cafe, Italian, Chinese, North Indian
# 446: North Indian, Mughlai, Continental, Chinese
# 447: Desserts, Fast Food, Ice Cream
# 448: South Indian, North Indian, Chinese, Street Food, Fast Food
# 449: Desserts, Mithai
# 450: North Indian, Mughlai, Chinese, Fast Food
# 451: Fast Food, North Indian, South Indian, Chinese, Street Food, Mithai
# 452: South Indian, Chinese, North Indian
# 453: Italian, Chinese, North Indian
# 454: European, Italian, Thai, Chinese, North Indian
# 455: Tibetan, Fast Food
# 456: North Indian, European, South Indian
# 457: Gujarati, Rajasthani, North Indian, Fast Food
# 458: Fast Food, North Indian, Mughlai
# 459: Continental, North Indian, American, Italian, Mexican
# 460: North Indian, Chinese, Mexican, Lebanese, Italian, Fast Food
# 461: Cafe, Pizza, Italian
# 462: American, Italian, North Indian, Chinese, Lebanese
# 463: Continental, Kashmiri, Italian, North Indian, Moroccan
# 464: Mediterranean, American, Asian
# 465: Italian, European
# 466: American, Continental, Italian
# 467: Seafood, Chinese, Japanese, Vietnamese, Asian, Thai
# 468: Cafe, Tea, Desserts
# 469: Italian, French, European, Cafe
# 470: Japanese, Thai, Italian, Asian
# 471: European, Continental, Pizza
# 472: Continental, American
# 473: American, European
# 474: Parsi, Iranian
# 475: Mithai, North Indian, South Indian, Chinese, Bakery
# 476: North Indian, Chinese, Italian, Fast Food
# 477: Fast Food, Bakery
# 478: Chinese, Italian, Fast Food
# 479: Lucknowi, Biryani
# 480: Desserts, Bakery, Fast Food
# 481: Hyderabadi, North Indian
# 482: North Indian, Chinese, Mughlai, Continental
# 483: North Indian, Fast Food, South Indian
# 484: North Indian, South Indian, Fast Food
# 485: South Indian, Fast Food, Street Food
# 486: Raw Meats, Street Food
# 487: Continental, Italian, North Indian
# 488: Cafe, Chinese
# 489: Mithai, North Indian, Chinese, Street Food
# 490: North Indian, Chinese, Street Food, Mithai
# 491: Mithai, North Indian, South Indian, Chinese, Street Food
# 492: Burger, Fast Food, Chinese, Bakery
# 493: Asian, Thai
# 494: North Indian, Mughlai, Nepalese, Tibetan, Korean
# 495: Tibetan, Chinese
# 496: Fast Food, South Indian, Chinese
# 497: Fast Food, South Indian
# 498: Fast Food, Mithai, Bakery
# 499: Chinese, Continental, Mexican
# 500: Bakery, Fast Food, Beverages
# 501: South Indian, Fast Food
# 502: Fast Food, Tea
# 503: Sushi, Asian
# 504: Cafe, Pizza
# 505: Mughlai, Fast Food, North Indian
# 506: North Indian, South Indian, Street Food, Chinese, Fast Food, Mithai
# 507: Continental, European, North Indian, French
# 508: North Indian, Street Food, South Indian, Mithai
# 509: Ice Cream, Street Food
# 510: Chinese, North Indian, Mithai, Street Food
# 511: North Indian, Mithai, Street Food
# 512: Cafe, Desserts, Bakery
# 513: American, Italian, Bakery, Deli, Burger, Sandwich, Pizza
# 514: American, Continental, Italian, Bakery
# 515: Desserts, Middle Eastern, Turkish
# 516: Desserts, Bakery
# 517: Japanese, Sushi
# 518: European, Lebanese, Mediterranean
# 519: North Indian, Mithai, South Indian, Street Food, Fast Food
# 520: North Indian, South Indian, Continental, Fast Food
# 521: Fast Food, North Indian, Bakery
# 522: North Indian, Mughlai, Chinese, Continental, Fast Food
# 523: North Indian, Fast Food, Biryani
# 524: Biryani, Chinese, North Indian
# 525: North Indian, Chinese, Mughlai, South Indian
# 526: Cafe, North Indian, Continental
# 527: Kerala
# 528: South Indian, Nepalese
# 529: European, North Indian
# 530: Naga, Chinese
# 531: Tibetan, South Indian, North Indian
# 532: Tibetan
# 533: North Indian, Chinese, Tibetan
# 534: Tibetan, Chinese, North Indian
# 535: Cafe, Tibetan
# 536: Nepalese, Tibetan
# 537: Mexican, Italian, North Indian, Continental, Asian
# 538: Cafe, Italian, Mexican, Salad, Desserts
# 539: North Indian, Italian
# 540: Italian, North Indian, Chinese, Mughlai
# 541: Chinese, Tibetan, Japanese
# 542: Thai, Chinese, North Indian
# 543: Thai, Japanese
# 544: Asian, North Indian, Continental
# 545: North Indian, Chinese, Seafood, Chettinad
# 546: North Indian, Continental, Asian, Chinese, Thai
# 547: North Indian, South Indian, Chinese, Mughlai
# 548: Lucknowi, Mughlai
# 549: Cafe, American, Italian
# 550: Cafe, Bakery, Parsi
# 551: Sushi, Japanese, Healthy Food
# 552: Cafe, Fast Food, Healthy Food
# 553: Biryani, Kerala
# 554: American, Asian, North Indian, Mexican, South Indian
# 555: Street Food, Desserts
# 556: South Indian, Chettinad
# 557: Asian, Thai, Chinese, North Indian
# 558: Chinese, North Indian, South Indian
# 559: Fast Food, Pizza, Burger
# 560: Mexican, North Indian
# 561: Street Food, Fast Food, Chinese, South Indian, North Indian
# 562: Cafe, Beverages
# 563: Fast Food, Raw Meats
# 564: Continental, Italian, Fast Food
# 565: Continental, North Indian, South Indian
# 566: Mithai, North Indian, South Indian, Chinese, Street Food, Bakery
# 567: Mithai, Bakery, North Indian
# 568: North Indian, Street Food, Fast Food
# 569: Fast Food, North Indian, South Indian
# 570: North Indian, Chinese, Italian, Finger Food
# 571: North Indian, European, Chinese
# 572: Salad, Healthy Food, Burger, Italian, Continental, Chinese, North Indian, Beverages
# 573: Mithai, South Indian
# 574: Street Food, South Indian, Chinese
# 575: North Indian, Mughlai, Fast Food
# 576: Seafood, North Indian
# 577: Burger, Pizza, Fast Food
# 578: South Indian, Chinese, Fast Food, Mithai
# 579: North Eastern, North Indian, Chinese
# 580: Fast Food, Street Food, Chinese
# 581: North Eastern, North Indian
# 582: South Indian, North Indian, Fast Food
# 583: Awadhi, Mughlai
# 584: Fast Food, Mughlai
# 585: South Indian, Fast Food, North Indian, Chinese
# 586: Chinese, Fast Food, North Indian
# 587: North Indian, Chinese, Street Food
# 588: Pizza, Fast Food, Bakery
# 589: Mithai, Chinese
# 590: Bakery, Pizza
# 591: Mithai, Street Food, North Indian
# 592: South Indian, Pizza, Chinese
# 593: Chinese, Bakery
# 594: Italian, Fast Food, South Indian
# 595: South Indian, Street Food, Desserts
# 596: Desserts, Ice Cream, Fast Food
# 597: Continental, European, North Indian
# 598: North Indian, Mughlai, Awadhi
# 599: Bengali, Chinese
# 600: Chinese, North Eastern
# 601: Chinese, Fast Food, Bakery
# 602: American, Tex-Mex, Italian, Mexican, North Indian
# 603: Ice Cream, Beverages, Fast Food
# 604: Finger Food, Italian, Middle Eastern
# 605: Bengali, Seafood
# 606: North Indian, Italian, Chinese, Thai
# 607: Fast Food, North Indian, Beverages
# 608: North Indian, Chinese, Italian, Mexican, Lebanese
# 609: North Indian, Chinese, Italian, Lebanese, Mexican
# 610: North Indian, Continental, Chinese, Fast Food
# 611: North Indian, Fast Food, Chinese, Mithai
# 612: Chinese, Seafood, Asian
# 613: North Indian, Street Food, South Indian, Fast Food, Chinese
# 614: Healthy Food, Juices
# 615: Ice Cream, Beverages
# 616: Italian, Continental, Fast Food, North Indian
# 617: North Indian, Street Food, Fast Food, Chinese, South Indian, Mithai
# 618: North Indian, Fast Food, Chinese, Japanese, Asian, Italian
# 619: Cafe, Fast Food, Asian, Italian
# 620: North Indian, Chinese, Tibetan, Italian, Fast Food
# 621: Chinese, Thai, Seafood, North Indian, Italian
# 622: Fast Food, Chinese, Mithai, Street Food
# 623: Fast Food, Continental, Italian, Bakery
# 624: Continental, Fast Food
# 625: North Indian, Chinese, Continental, Thai
# 626: Cafe, Italian
# 627: Ice Cream, Bakery
# 628: Beverages, Healthy Food
# 629: Fast Food, Italian, Pizza
# 630: Desserts, Fast Food, Chinese
# 631: North Indian, Kashmiri, Mughlai
# 632: North Indian, Chinese, Seafood
# 633: Continental, Italian, North Indian, Lebanese
# 634: Street Food, South Indian
# 635: Bakery, Fast Food, Chinese
# 636: Chinese, Italian, Continental
# 637: Cafe, North Indian, Chinese
# 638: Hyderabadi, Fast Food
# 639: Continental, North Indian
# 640: Fast Food, Healthy Food
# 641: Fast Food, Desserts, Beverages
# 642: North Indian, Mithai, South Indian, Street Food, Chinese
# 643: North Indian, South Indian, Bihari
# 644: Asian, North Indian, Japanese
# 645: North Indian, South Indian, Fast Food, Street Food, Chinese, Mithai
# 646: North Indian, Continental, Mughlai
# 647: Street Food, Mughlai
# 648: Tea, Beverages, Fast Food
# 649: Fast Food, Chinese, North Indian
# 650: North Indian, South Indian, Fast Food, Street Food, Chinese, Beverages, Mithai
# 651: Japanese, Chinese
# 652: North Indian, Continental, Italian, Thai, Chinese
# 653: Chinese, North Indian, Continental, Italian
# 654: Fast Food, Turkish
# 655: North Indian, Finger Food, Italian, Chinese
# 656: Lebanese, Chinese
# 657: Italian, Continental, North Indian
# 658: North Indian, Chinese, Mexican, Italian, Thai, Lebanese
# 659: Fast Food, Mughlai, Armenian
# 660: South Indian, Chinese, Mithai
# 661: South Indian, Biryani
# 662: North Indian, Mughlai, Armenian
# 663: North Indian, South Indian, Bakery, Italian
# 664: Street Food, North Indian, Chinese, Continental
# 665: North Indian, Beverages
# 666: Italian, Continental, Fast Food, Chinese
# 667: Fast Food, Maharashtrian, North Indian
# 668: Raw Meats, North Indian
# 669: Cafe, Fast Food, Pizza
# 670: Cafe, South Indian, North Indian, Bakery
# 671: North Indian, Biryani, Fast Food
# 672: Bakery, Desserts, Fast Food, Street Food, Chinese, Beverages
# 673: Thai, European, Mexican, North Indian, Chinese, Cafe
# 674: American, Asian, European, Seafood
# 675: North Indian, Mexican, Chinese, Italian
# 676: North Indian, Fast Food, Italian, Chinese, Cafe
# 677: Continental, North Indian, Chinese, Italian, Finger Food
# 678: Continental, Chinese, Thai, Mughlai, North Indian
# 679: Healthy Food, Italian, Juices, Beverages
# 680: North Indian, Mughlai, Lebanese
# 681: Cafe, Continental, Italian, North Indian
# 682: Continental, Fast Food, North Indian, Asian
# 683: Chinese, Thai, Continental, North Indian
# 684: Continental, Italian, American
# 685: Cafe, Asian, Italian, North Indian
# 686: Continental, Italian, North Indian, Chinese
# 687: North Indian, Mangalorean, Chinese
# 688: Kashmiri, North Indian, Mughlai, South Indian, Maharashtrian, Gujarati
# 689: North Indian, Continental, Mughlai, Asian
# 690: Continental, North Indian, Chinese, Asian
# 691: Continental, Italian, Mediterranean, Asian
# 692: Continental, Modern Indian, Asian
# 693: Fast Food, North Indian, Chinese, South Indian, Ice Cream
# 694: Bakery, Chinese, Fast Food
# 695: North Indian, Chinese, South Indian, Street Food, Fast Food, Mithai
# 696: North Indian, Chinese, Raw Meats
# 697: South Indian, Street Food, Mithai
# 698: North Indian, Continental, European, American, Mediterranean
# 699: Naga, Tibetan
# 700: Chinese, Tibetan, Fast Food
# 701: Cafe, Korean
# 702: North Indian, Tibetan
# 703: Cafe, American, Continental, Nepalese
# 704: Continental, Chinese, Fast Food
# 705: Assamese
# 706: European, Asian
# 707: Mexican, American
# 708: Mithai, Street Food, North Indian, South Indian, Chinese
# 709: Desserts, Ice Cream, Pizza
# 710: Finger Food, North Indian, Continental, Chinese, Italian
# 711: Pizza, North Indian, Continental
# 712: Chinese, Asian, Mediterranean, Continental
# 713: Cafe, Italian, Lebanese, Continental, Mediterranean
# 714: South American
# 715: Arabian, North Indian
# 716: North Indian, South Indian, Mughlai
# 717: Cafe, Fast Food
# 718: Cafe, Continental, Italian, Mexican, Chinese, American
# 719: Italian, Continental, Mexican, North Indian
# 720: Fast Food, Italian, Beverages
# 721: Continental, American, Italian, North Indian, Chinese
# 722: Street Food, Chinese, North Indian
# 723: Cafe, Continental, Italian, Chinese
# 724: Cafe, North Indian, Continental, Chinese
# 725: Cafe, Continental, Chinese, North Indian, Italian
# 726: Cafe, Continental, Italian
# 727: Cafe, North Indian, Chinese, Continental
# 728: Cafe, Continental, North Indian, Chinese, Mexican
# 729: Hyderabadi, Biryani, North Indian
# 730: Asian, Chinese, Thai, Japanese
# 731: Italian, Mexican, Spanish, Thai, Vietnamese, Indonesian, American
# 732: South Indian, Fast Food, Chinese
# 733: North Indian, Chinese, South Indian, Bakery
# 734: Pizza, Burger, Fast Food
# 735: Cafe, North Indian, Chinese, South Indian
# 736: Asian, North Indian
# 737: North Indian, Continental, Salad
# 738: Asian, Chinese, Thai, Vietnamese
# 739: Cafe, Continental, Italian, Mexican
# 740: Cafe, Bakery, Italian
# 741: Desserts, North Indian
# 742: Pizza, Ice Cream
# 743: North Indian, Street Food, Chinese
# 744: Seafood, Italian
# 745: North Indian, Continental, European, Chinese, Thai
# 746: Afghani, North Indian, Pakistani, Arabian
# 747: Chinese, Continental, Thai
# 748: Cafe, Fast Food, Bakery
# 749: Continental, European
# 750: European
# 751: Continental, North Indian, European, Asian
# 752: North Indian, Continental, Lebanese
# 753: Italian, Continental, Finger Food
# 754: Cafe, American, Tea
# 755: Spanish, Italian
# 756: Chinese, Cafe
# 757: Mughlai, North Indian, South Indian
# 758: French, Italian
# 759: Mughlai, Italian, Finger Food, Middle Eastern
# 760: Continental, Italian, American, North Indian
# 761: Continental, Italian, Mediterranean
# 762: Finger Food, Continental, Italian, Chinese
# 763: Thai, Chinese, Japanese
# 764: Mediterranean, European
# 765: North Indian, European, Continental
# 766: Malaysian, Thai
# 767: North Indian, European, Asian
# 768: European, American
# 769: North Indian, Fast Food, Afghani
# 770: Beverages, Ice Cream
# 771: North Indian, Mughlai, Chinese, Bakery
# 772: Mithai, North Indian, South Indian
# 773: Street Food, Chinese, Mithai
# 774: Bakery, Street Food
# 775: Fast Food, South Indian, Chinese, Mithai
# 776: Ice Cream, Desserts, Fast Food
# 777: Chinese, Seafood, Japanese
# 778: Continental, Seafood, North Indian
# 779: Continental, Italian, North Indian, Chinese, Lebanese
# 780: Cafe, American, Italian, North Indian, Chinese
# 781: North Indian, Chinese, South Indian, Mithai
# 782: Japanese, Chinese, Asian, Malaysian, Thai, Vietnamese
# 783: Finger Food, Continental, Italian
# 784: Street Food, Bakery
# 785: Raw Meats
# 786: Continental, Chinese, Italian, Cafe
# 787: Continental, Mexican
# 788: Cafe, Mexican, Italian, North Indian, Chinese
# 789: North Indian, Chinese, Continental, Italian, Mexican, Lebanese
# 790: American, Italian, Cafe
# 791: Chinese, Thai, Tibetan, Japanese
# 792: Cafe, Italian, Continental, Mexican, Mediterranean
# 793: North Indian, Continental, Italian, Chinese
# 794: Cafe, Italian, Fast Food
# 795: Chinese, Biryani, North Indian
# 796: Bakery, Fast Food, Pizza
# 797: Bakery, Desserts, Fast Food, Pizza, Burger, Finger Food
# 798: Chinese, Fast Food, North Indian, South Indian, Street Food, Mithai
# 799: North Indian, Chinese, Bakery
# 800: Mughlai, Chinese, North Indian
# 801: North Indian, South Indian, Mithai
# 802: Lebanese, North Indian, Fast Food
# 803: Awadhi
# Select a cuisine (enter index): 803
# Restaurant Name: Zareen's Dastarkhwan
# Rating: 0.0
# Votes: 1
# Location: 28.56519398, 77.28569627
# ------------------------------
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c85c77c176ec3b9650afc667d383b511 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c85c77c176ec3b9650afc667d383b511&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c85c77c176ec3b9650afc667d383b511 = L.map(
#                 &quot;map_c85c77c176ec3b9650afc667d383b511&quot;,
#                 {
#                     center: [28.56519398, 77.28569627],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ca465a184c4162b2b1ff66b62586e7ae = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ca465a184c4162b2b1ff66b62586e7ae.addTo(map_c85c77c176ec3b9650afc667d383b511);
#
#
#             var marker_2ef05ab1aaf2dacde545d1480f9f96e8 = L.marker(
#                 [28.56519398, 77.28569627],
#                 {}
#             ).addTo(map_c85c77c176ec3b9650afc667d383b511);
#
#
#             var icon_1d338fc2578705b8153ee2d9622c14f5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2ef05ab1aaf2dacde545d1480f9f96e8.setIcon(icon_1d338fc2578705b8153ee2d9622c14f5);
#
#
#         var popup_638034f00687ec58c5eb65f2eb62df35 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_db79e75e69de93bf9051db102f20106c = $(`&lt;div id=&quot;html_db79e75e69de93bf9051db102f20106c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Zareen&#x27;s Dastarkhwan&lt;br&gt;Rating: 0.0&lt;br&gt;Votes: 1&lt;/div&gt;`)[0];
#                 popup_638034f00687ec58c5eb65f2eb62df35.setContent(html_db79e75e69de93bf9051db102f20106c);
#
#
#
#         marker_2ef05ab1aaf2dacde545d1480f9f96e8.bindPopup(popup_638034f00687ec58c5eb65f2eb62df35)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Conclusion
#
# In this task, we developed a restaurant recommendation system that enables users to find top dining options based on their preferences for cuisine and location. The process involved several key steps, including data preprocessing, user input handling, filtering the dataset, and visualizing results on a map.
#
# ### Key Features:
#
# - **User-Centric Design**: The system allows users to select their country, city, and desired cuisine through an interactive interface, enhancing the overall user experience.
#
# - **Data Filtering and Sorting**: We efficiently filtered and sorted restaurant data based on user selections, ensuring that only relevant options are presented.
#
# - **Visual Mapping**: By leveraging the Folium library, we visualized the locations of the top-rated restaurants on an interactive map, making it easier for users to explore their options in real time.
#
# ### Future Improvements:
#
# While the current implementation provides a solid foundation, there are several potential improvements for future iterations:
#
# 1. **Enhanced Filtering Options**: Implement additional filters such as price range, dietary restrictions, and restaurant features (e.g., outdoor seating, pet-friendly).
#
# 2. **User Feedback System**: Allow users to rate and review restaurants after their visit, providing more data for refining recommendations.
#
# 3. **Integration with External APIs**: Explore integrating with restaurant review platforms or delivery services to provide real-time data and enhance user engagement.
#
# Overall, this project successfully demonstrates how to combine data processing, user interaction, and visualization techniques to create a functional and engaging restaurant recommendation system. The approach taken can be adapted and expanded upon for various applications in data science and machine learning.
